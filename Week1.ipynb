# %% [markdown]
# <a href="https://colab.research.google.com/github/daffayudisaa/PCVK_Ganjil_2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
#membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://awsimages.detik.net.id/community/media/visual/2023/09/02/kucing-ragdoll_169.jpeg?w=600&q=90"]

#baca dan tampilkan imaga
#loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=600x170>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi Image =", tinggi, "x", lebar, "\nTinggi =", tinggi, "\nLebar =", lebar)
cv2_imshow(image_2)
# Out:
# Resolusi Image = 170 x 300
# Tinggi = 170
# Lebar = 300
# <PIL.Image.Image image mode=RGB size=300x170>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal di tengah image
for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=600x170>

# %% [markdown]
# **Pertanyaan:**
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# ![{F05B932F-7137-4158-B33C-67FE8E48FD4B}.png](data:image/png;base64,...)
#
#   Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak dilakukan?
# 4. Perhatikan potongan kode progam berikut :
#
#   ![{578B1A29-95C3-436F-BDF9-D8B4EE7432C5}.png](data:image/png;base64,...)
#
#     Apakah kegunaan kode [255,255,255] ? Jelaskan!
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!

# %% [markdown]
# **Jawaban:**
# 1. Pengeksekusian python pada praktikum kali ini menggunakan google colab karena kemudahan aksesibilitas. Dimana user bisa menjalankan berbagai macam library tanpa harus menginstall. Selain itu google colab yang berbasis cloud memudahkan user dalam mengakses praktikum ini kapanpun dimanapun (tidak harus pada penyimpanan lokal).
#
# 2. Kegunaan setiap library pada praktikum ini:
#
#   * numpy --> Digunakan untuk operasi matematika dan manipulasi array (misalnya, pemrosesan data numerik).
#
#   * pandas --> Digunakan untuk membaca data dari berbagai format (CSV, Excel, dll.), membersihkan data, dan melakukan analisis statistik.
#
#   * cv2 (open cv) --> Digunakan untuk pemrosesan gambar dan video
#
#   * cv2_imshow --> Fungsi tambahan dari Google Colab untuk menampilkan gambar saat menggunakan OpenCV, karena fungsi standar imshow tidak bekerja di Colab.
#
#   * skimage --> Digunakan untuk membaca dan menulis gambar.
#
#   * PIL import Image -->  Digunakan untuk manipulasi gambar (misalnya, membuka, mengubah, atau menyimpan gambar).
#
#   * matplotlib.pylab --> Digunakan untuk visualisasi data, seperti plotting grafik atau menampilkan gambar.
#
# 3. Kode ini menggunakan fungsi cv.resize dari OpenCV. Dalam fungsi ini, ukuran gambar tidak ditentukan secara langsung melalui parameter dimensi (lebar dan tinggi), melainkan dengan menggunakan faktor skala. Nilai (0, 0) di sini berarti ukuran akhir gambar akan dihitung berdasarkan faktor skala yang diberikan.
#
#     * fx=0.5: Menentukan faktor skala untuk sumbu horizontal (x-axis), yang berarti gambar akan diperkecil menjadi 50% dari lebar aslinya.
#     * fy=0.5: Menentukan faktor skala untuk sumbu vertikal (y-axis), yang berarti gambar akan diperkecil menjadi 50% dari tinggi aslinya.
#
#     Dengan demikian, hasil dari kode ini adalah gambar yang ukurannya menjadi setengah dari ukuran aslinya, baik dalam arah horizontal maupun vertikal.
#
# 4. Potongan kode tersebut menggunakan format RGB (Red, Green, Blue) untuk menentukan warna, di mana [255, 255, 255] adalah kode untuk warna putih. Fungsi dari potongan kode tersebut adalah untuk mengatur warna piksel pada posisi tertentu, yakni membentuk garis horizontal putih di tengah gambar.
#
# 5.  Piksel adalah unit terkecil dari gambar digital yang menyimpan informasi warna. Resolusi gambar merujuk pada jumlah piksel dalam dimensi horizontal dan vertikal, seperti 1920x1080. Gambar dengan resolusi tinggi memiliki lebih banyak piksel, sehingga dapat menampilkan lebih banyak detail dan kejelasan. Sebaliknya, gambar dengan resolusi rendah memiliki lebih sedikit piksel, yang sering kali menghasilkan kualitas gambar yang kurang tajam. Resolusi yang lebih tinggi berarti gambar lebih detail dan jelas, sementara resolusi yang lebih rendah berarti gambar lebih buram dan kurang detail.

# %% [markdown]
# **Tugas**
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
# gambar

# %%
#Tugas - Buat garis vertikal dan garis menyilang diagonal pada image keluaran
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal di tengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

#membuat garis menyilang diagonal di tengah image
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#diagonal dari kiri atas ke kanan bawah
for y in range(tinggi):
    x = int((lebar / tinggi) * y)
    image_3[y, x] = [255, 255, 255]

#diagonal dari kanan atas ke kiri bawah
for y in range(tinggi):
    x = int((lebar / tinggi) * (tinggi - y - 1))
    image_3[y, x] = [255, 255, 255]

#menampilkan image
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=600x170>
# <PIL.Image.Image image mode=RGB size=600x170>

# %%
#Tugas - Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang tertentu
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah image (loop)
for y in range(100,200):
  image_3[int(tinggi/2), y] = [255, 255, 255]

#menampilkan image
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=600x170>

# %%
#Tugas - Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

x1, y1 = 50,150
x2, y2 = 100,200

#isi bagian dalam kotak
for x in range(x1, x2):
    for y in range(y1, y2):
        image_3[x, y] = [255, 255, 255]

#menampilkan image
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=600x170>

# %% [markdown]
# **Tugas Kelompok**
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# Membaca gambar dari lokasi drive
print('Menggunakan Matplotlib')
ktp = cv.imread('/content/drive/MyDrive/PCVK/ktp_contoh.jpg')
plt.imshow(ktp)
# Out:
# Menggunakan Matplotlib

# %%
print('Menggunakan Open CV Untuk Menampilka Gambar')
cv2_imshow(ktp)

print('Menggunakan Matplotlib Untuk Menampilka Gambar Setelah Dikonversi')
ktp2 = cv.cvtColor(ktp, cv.COLOR_BGR2RGB)
plt.imshow(ktp2)
# Out:
# Menggunakan Open CV Untuk Menampilka Gambar
# <PIL.Image.Image image mode=RGB size=800x488>
# Menggunakan Matplotlib Untuk Menampilka Gambar Setelah Dikonversi

# %% [markdown]
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv
#
#   **Jawab :**
#   OpenCV membaca dan menampilkan gambar dalam format BGR (Blue, Green, Red). Karena itu, saat menggunakan cv.imshow() atau cv2_imshow(), tidak diperlukan konversi warna.
#
#   Namun, Matplotlib mengharapkan gambar dalam format RGB (Red, Green, Blue). Jika gambar dari OpenCV (BGR) ditampilkan langsung di Matplotlib tanpa konversi, warnanya akan salah. Oleh karena itu, kita perlu mengonversi gambar dari BGR ke RGB menggunakan cv.cvtColor() sebelum menampilkannya dengan plt.imshow().

# %%
img = np.copy(ktp_2)

#Menutup bagian TTL
for y in range (95,270): #untuk mengatur panjang blok
  for x in range (70,80): #untuk mengatur tinggi blok
    img[x,y] = [0,255,255]

#Menutup bagian Jenis Kelamin
for y in range (95,150): #untuk mengatur panjang blok
  for x in range (80,90): #untuk mengatur tinggi blok
    img[x,y] = [0,0,0]

plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.axis('on')  # Menampilkan sumbu
plt.show()
